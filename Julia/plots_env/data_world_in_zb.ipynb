# %%
using Plots

# %%
#https://www.statista.com/statistics/871513/worldwide-data-created/#:~:text=The%20total%20amount%20of%20data,replicated%20reached%20a%20new%20high.

zeta_world = [2, 5, 6.5, 9, 12.5, 15.5, 18, 26, 33, 41, 64.2, 79]
years = 2010:2021
length(zeta_world), length(years)
# Out:
# (12, 12)

# %%
bar(years,zeta_world,xticks = years,label = :none,xlabel = "Year", ylabel = "Data volume in zetabytes",ylim = (0,100))

# %%
savefig("../LaTeXBook/figures/chapter_1_figures/years_data_zb.pdf")
