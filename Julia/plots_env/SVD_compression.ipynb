# %%
using LinearAlgebra, Images, Plots, LaTeXStrings, Measures

# %%
img = Gray.(load("../../data/dude-color-small.png"))
@show size(img)
@show typeof(img)
img
# Out:
# size(img) = (353, 469)
# typeof(img) = Matrix{Gray{N0f8}}
# 353×469 Array{Gray{N0f8},2} with eltype Gray{N0f8}:
#  Gray{N0f8}(0.4)    Gray{N0f8}(0.404)  …  Gray{N0f8}(0.353)
#  Gray{N0f8}(0.4)    Gray{N0f8}(0.404)     Gray{N0f8}(0.357)
#  Gray{N0f8}(0.4)    Gray{N0f8}(0.396)     Gray{N0f8}(0.357)
#  Gray{N0f8}(0.396)  Gray{N0f8}(0.396)     Gray{N0f8}(0.357)
#  Gray{N0f8}(0.392)  Gray{N0f8}(0.396)     Gray{N0f8}(0.357)
#  Gray{N0f8}(0.392)  Gray{N0f8}(0.396)  …  Gray{N0f8}(0.357)
#  Gray{N0f8}(0.388)  Gray{N0f8}(0.392)     Gray{N0f8}(0.357)
#  Gray{N0f8}(0.388)  Gray{N0f8}(0.392)     Gray{N0f8}(0.353)
#  Gray{N0f8}(0.388)  Gray{N0f8}(0.388)     Gray{N0f8}(0.357)
#  Gray{N0f8}(0.388)  Gray{N0f8}(0.388)     Gray{N0f8}(0.251)
#  Gray{N0f8}(0.388)  Gray{N0f8}(0.388)  …  Gray{N0f8}(0.22)
#  Gray{N0f8}(0.388)  Gray{N0f8}(0.388)     Gray{N0f8}(0.22)
#  Gray{N0f8}(0.388)  Gray{N0f8}(0.384)     Gray{N0f8}(0.216)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.318)  Gray{N0f8}(0.341)     Gray{N0f8}(0.357)
#  Gray{N0f8}(0.325)  Gray{N0f8}(0.337)     Gray{N0f8}(0.275)
#  Gray{N0f8}(0.325)  Gray{N0f8}(0.365)     Gray{N0f8}(0.357)
#  Gray{N0f8}(0.337)  Gray{N0f8}(0.337)     Gray{N0f8}(0.337)
#  Gray{N0f8}(0.322)  Gray{N0f8}(0.345)  …  Gray{N0f8}(0.325)
#  Gray{N0f8}(0.349)  Gray{N0f8}(0.384)     Gray{N0f8}(0.286)
#  Gray{N0f8}(0.376)  Gray{N0f8}(0.404)     Gray{N0f8}(0.329)
#  Gray{N0f8}(0.373)  Gray{N0f8}(0.365)     Gray{N0f8}(0.353)
#  Gray{N0f8}(0.427)  Gray{N0f8}(0.455)     Gray{N0f8}(0.31)
#  Gray{N0f8}(0.573)  Gray{N0f8}(0.627)  …  Gray{N0f8}(0.337)
#  Gray{N0f8}(0.663)  Gray{N0f8}(0.686)     Gray{N0f8}(0.329)
#  Gray{N0f8}(0.698)  Gray{N0f8}(0.702)     Gray{N0f8}(0.341)

# %%
X = convert(Matrix{Float32},img)
heatmap(X,yflip=true,color=:greys,legend=false,aspectratio=1.2)

# %%
function rank_approx(F::SVD, k)
    U, S, V = F
    M = U[:, 1:k] * Diagonal(S[1:k]) * V[:, 1:k]'
    clamp01!(M)
end
# Out:
# rank_approx (generic function with 1 method)

# %%
F = svd(X)
X10 = rank_approx(F,10)
X30 = rank_approx(F,30)
X50 = rank_approx(F,50);

# %%
sum(F.S)
# Out:
# 604.36005f0

# %%
total_errs =sum(F.S .^2)
# Out:
# 37815.484f0

# %%
rel_errs = [sum(F.S[i:end].^2) for i in 5:100]/total_errs;

# %%
plot(   5:100,rel_errs,
        label=false,markershape=:circle,xticks=5:5:100,yticks=0:0.02:0.1,
        ms=4,xlabel="Rank of Approximation  "*L"q",ylabel="Relative Approximation Error",guidefont=font(15),
        ylim=(0,0.1),size=(1000,600),    margin=20mm,c=:black)
heatmap!(X10,yflip=true,legend=false, color = :greys,ticks=false,  
         inset = (1,bbox(-0.3, -0.45, 0.3, 0.3, :center)),
        subplot = 2,
        label=false,title=" "^23*L"q=10",titlefontsize=13,aspectratio=0.8,axis=false)
heatmap!(X30,yflip=true,legend=false, color = :greys,ticks=false,  
         inset = (1,bbox(-0.13, -0.11, 0.3, 0.3, :center)),
        subplot = 3,
        label=false,title=" "^23*L"q=30",titlefontsize=13,aspectratio=0.8,axis=false)
heatmap!(X50,yflip=true,legend=false, color = :greys,ticks=false,  
         inset = (1,bbox(0.03, 0.22, 0.3, 0.3, :center)),
        subplot = 4,
        label=false,title=" "^23*L"q=50",titlefontsize=13,aspectratio=0.8,axis=false)
heatmap!(X,yflip=true,legend=false, color = :greys,ticks=false,  
         inset = (1,bbox(0.36, 0.28, 0.3, 0.3, :center)),
        subplot = 5,
        label=false,title=" "^18*"Original Image",titlefontsize=10,aspectratio=0.8,axis=false)
quiver!([20], [0.08], quiver=([10-20], [rel_errs[10-5+1]-0.08]),c=:black,lw=2)
quiver!([40], [0.05], quiver=([30-40], [rel_errs[30-5+1]-0.05]),c=:black,lw=2)
quiver!([58], [0.02], quiver=([50-58], [rel_errs[50-5+1]-0.02]),c=:black,lw=2)

# %%
savefig("~/Dropbox/MathEngDeepLearningBook/LaTeXBook/figures/chapter_2_figures/SVD_compress.pdf")

# %%
# plot(   5:100,F.S[5:100],
#         label=false,markershape=:circle,xticks=10:10:100,yticks=5:5:30,
#         ms=4,xlabel="Index  "*L"i",ylabel="Singular Values  "*L"\delta_i",guidefont=font(16),
#         ylim=(0,30),size=(1000,600),    margin=20mm,c=:black)
# heatmap!(X10,yflip=true,legend=false, color = :greys,ticks=false,  
#          inset = (1,bbox(-0.32, -0.45, 0.3, 0.3, :center)),
#         subplot = 2,
#         label=false,title=L"q=10",titlefontsize=10)
# heatmap!(X30,yflip=true,legend=false, color = :greys,ticks=false,  
#          inset = (1,bbox(-0.13, -0.11, 0.3, 0.3, :center)),
#         subplot = 3,
#         label=false,title=" "^10*L"q=30",titlefontsize=10)
# heatmap!(X50,yflip=true,legend=false, color = :greys,ticks=false,  
#          inset = (1,bbox(0.03, 0.22, 0.3, 0.3, :center)),
#         subplot = 4,
#         label=false,title=" "^20*L"q=50",titlefontsize=10)
# heatmap!(X,yflip=true,legend=false, color = :greys,ticks=false,  
#          inset = (1,bbox(0.36, 0.28, 0.3, 0.3, :center)),
#         subplot = 5,
#         label=false,title="Original Image",titlefontsize=10)
# quiver!([20], [25], quiver=([10-20], [F.S[10]-25]),c=:black,lw=2)
# quiver!([44], [20], quiver=([30-44], [F.S[30]-20]),c=:black,lw=2)
# quiver!([55], [5], quiver=([50-55], [F.S[50]-5]),c=:black,lw=2)

# %%
savefig("SVD_compress.pdf")

# %%
353*469
# Out:
# 165557

# %%
50*(1+353+469)
# Out:
# 41150

# %%
41150/165557
# Out:
# 0.24855487838025575
